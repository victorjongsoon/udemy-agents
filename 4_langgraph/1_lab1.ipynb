# %% [markdown]
# ## Welcome back to Python Notebooks!
#
# Didja miss me??
#
# ### And welcome to Week 4, Day 2 - introducing LangGraph!

# %%
from typing import Annotated
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.graph import StateGraph
from langgraph.graph.message import add_messages
from langchain_openai import ChatOpenAI
from pydantic import BaseModel
import random

# %%
# Some useful constants

nouns = ["Cabbages", "Unicorns", "Toasters", "Penguins", "Bananas", "Zombies", "Rainbows", "Eels", "Pickles", "Muffins"]
adjectives = ["outrageous", "smelly", "pedantic", "existential", "moody", "sparkly", "untrustworthy", "sarcastic", "squishy", "haunted"]

# %%
# Our favorite first step! Crew was doing this for us, by the way.
load_dotenv(override=True)
# Out:
# True

# %%
def shout(text: Annotated[str, "something to be shouted"]) -> str:
    print(text.upper())
    return text.upper()

shout("hello")
# Out:
# HELLO
# 'HELLO'

# %% [markdown]
# ### A word about "Annotated"
#
# You probably know this; type hinting is a feature in Python that lets you specify the type of something:
#
# `my_favorite_things: List`
#
# But you may not know this:
#
# You can also use something called "Annotated" to add extra information that somebody else might find useful:
#
# `my_favorite_things: Annotated[List, "these are a few of mine"]`
#
# LangGraph needs us to use this feature when we define our State object.
#
# It wants us to tell it what function it should call to update the State with a new value.
#
# This function is called a **reducer**.
#
# LangGraph provides a default reducer called `add_messages` which takes care of the most common case.
#
# And that hopefully explains why the State looks like this.

# %% [markdown]
# ### Step 1: Define the State object
#
# You can use any python object; but it's most common to use a TypedDict or a Pydantic BaseModel.

# %%
class State(BaseModel):
        
    messages: Annotated[list, add_messages]

# %% [markdown]
# ### Step 2: Start the Graph Builder with this State class

# %%
graph_builder = StateGraph(State)

# %% [markdown]
# ### Step 3: Create a Node
#
# A node can be any python function.
#
# The reducer that we set before gets automatically called to combine this response with previous responses

# %%
def our_first_node(old_state: State) -> State:

    reply = f"{random.choice(nouns)} are {random.choice(adjectives)}"
    messages = [{"role": "assistant", "content": reply}]

    new_state = State(messages=messages)

    return new_state

graph_builder.add_node("first_node", our_first_node)

# %% [markdown]
# ### Step 4: Create Edges

# %%
graph_builder.add_edge(START, "first_node")
graph_builder.add_edge("first_node", END)

# %% [markdown]
# ### Step 5: Compile the Graph

# %%
graph = graph_builder.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### That's it! Showtime!

# %%
def chat(user_input: str, history):
    message = {"role": "user", "content": user_input}
    messages = [message]
    state = State(messages=messages)
    result = graph.invoke(state)
    print(result)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# {'messages': [HumanMessage(content='What is state in langgraph?', additional_kwargs={}, response_metadata={}, id='4c7f9235-d642-466c-95a5-d10e639ffb0c'), AIMessage(content='Rainbows are smelly', additional_kwargs={}, response_metadata={}, id='6ec68e63-7544-4fe9-a6ae-c17bff639127')]}

# %% [markdown]
# ### But why did I show you that?
#
# To make the point that LangGraph is all about python functions - it doesn't need to involve LLMs!!
#
# Now we'll do the 5 steps again, but in 1 shot:

# %%
# Step 1: Define the State object
class State(BaseModel):
    messages: Annotated[list, add_messages]

# %%
# Step 2: Start the Graph Builder with this State class
graph_builder = StateGraph(State)

# %%
# Step 3: Create a Node

llm = ChatOpenAI(model="gpt-4o-mini")

def chatbot_node(old_state: State) -> State:
    response = llm.invoke(old_state.messages)
    new_state = State(messages=[response])
    return new_state

graph_builder.add_node("chatbot", chatbot_node)

# %%
# Step 4: Create Edges
graph_builder.add_edge(START, "chatbot")
graph_builder.add_edge("chatbot", END)

# %%
# Step 5: Compile the Graph
graph = graph_builder.compile()
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### That's it! And, let's do this:

# %%
def chat(user_input: str, history):
    initial_state = State(messages=[{"role": "user", "content": user_input}])
    result = graph.invoke(initial_state)
    print(result)
    return result['messages'][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# {'messages': [HumanMessage(content='What is state in lang graph?', additional_kwargs={}, response_metadata={}, id='cd7f43eb-837f-47b4-858f-bb836f1cbdde'), AIMessage(content='In the context of graph theory and computer science, particularly in areas such as state machines, automata theory, and graph algorithms, a **state** typically refers to a specific configuration or condition of a system at a given point in time. When we discuss states in relation to state graphs or state machines, here are key points to consider:\n\n1. **State Representation**: A state can represent various aspects of a system or process, such as values of variables, a particular point in a computation, or an operational mode of a system.\n\n2. **Graph Structure**: A state graph (or state transition graph) consists of vertices (nodes) representing the states of the system, and directed edges (arcs) representing transitions between those states. Transitions are often triggered by inputs or events.\n\n3. **Initial State**: In many state graphs, there is a designated initial state from which the system begins its operation.\n\n4. **Final States**: Some state systems have designated final or accepting states, which signify the completion of a process or successful recognition of an input pattern, especially in the case of finite state machines.\n\n5. **Dynamic Behavior**: The transitions between states can be governed by rules or conditions, and the behavior of the system can be analyzed by examining how it moves from one state to another in response to inputs.\n\n6. **Applications**: State graphs are used in various applications, including designing digital circuits, modeling algorithms, parsing languages, and simulating processes in computer science.\n\nIn summary, a state in a state graph is a fundamental component that helps in modeling dynamic systems by capturing their various conditions and transitions through a structured representation.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 334, 'prompt_tokens': 14, 'total_tokens': 348, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0gFohAXa3VgZF6ZxbAfcqmwEsfDG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--7c0455b8-b57d-40ee-a4e0-633188db32c5-0', usage_metadata={'input_tokens': 14, 'output_tokens': 334, 'total_tokens': 348, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'messages': [HumanMessage(content='So previous state also known as previous conversation is context for the next conversation?', additional_kwargs={}, response_metadata={}, id='b22086bd-e810-4887-af9f-711e0aed7d5a'), AIMessage(content="Yes, the previous state or conversation context can provide background and continuity for the next conversation. In a dialogue, remembering past interactions can help create a more coherent and relevant experience. However, each new session typically starts without memory of past conversations unless specifically designed to retain and reference that context. In this chat, I don't have memory of past interactions, so I won't recall details from future conversations after this one ends.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 82, 'prompt_tokens': 22, 'total_tokens': 104, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0gGR0LB4b2C6DWYKSCcdIETf4ZPa', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--a64fd423-2ffc-470a-b6be-3a7b4b060261-0', usage_metadata={'input_tokens': 22, 'output_tokens': 82, 'total_tokens': 104, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
